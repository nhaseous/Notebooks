# %%
from _pricechecker import pricechecker
import time

# Main

start_time = time.time()

# print("Enter username: \n")
# user1 = input()
user1 = "curefortheitch"

try:
    inventory = pricechecker.get_inventory(user1)

    inventory_list = []
    sorted_inventory_list = [[],[],[],[],[],[],[],[],[],[]]

    print("Loading inventory...\n")
    for release in inventory:
        pricechecker.get_listings(sorted_inventory_list, inventory_list, user1, release[0], release[1])

    '''
    choice = "0"
    while choice != "5":
        print('─' * 50)
        print("Choose option:\n(1) Print sorted list.\n(2) Print unsorted list.\n(3) Check for changes.\n(4) Save inventory list.\n(5) Quit.\n")
        # choice = input()
        print('─' * 50)
        
        if choice == "1":
            pricechecker.print_sorted_list(sorted_inventory_list)
        elif choice == "2":
            pricechecker.print_list(inventory_list)
        elif choice == "3":
            pricechecker.compare_inventory_list(inventory_list)
        elif choice == "4":
            pricechecker.save_state(inventory_list)
            print("Saved inventory list as pickle.\n")
        elif choice != "5":
            print("Command not recognized.")
        choice = "5"
    '''
        
    # pricechecker.save_state(inventory_list) # Save
    
    pricechecker.compare_inventory_list(inventory_list) # Compare
    # pricechecker.print_sorted_list(sorted_inventory_list) # Print sorted

            
except AttributeError:
    print("No user found.")

end_time = time.time()

print("Done.\n")
print("Total time: {0} seconds".format(end_time-start_time))
# Out:
# Loading inventory...
#
# Loaded saved inventory state.
#
# (21)
# Flatbush Zombies - 3001: A Laced Odyssey (2xLP, Album, Ltd, Num, RE, S/Edition, Pin)
# https://www.discogs.com/sell/release/22031233?ships_from=United+States&sort=price%2Casc
# $64.00 total (M/M)
# $66.49 total (NM/NM)
# $63.99 total (M/NM)
# $70.00 total (M/M)
# $70.00 total (M/M)
# $74.99 total (M/M)
# $75.00 total (M/M) (You) (7)
# $75.94 total (NM/NM)
# $79.97 total (M/M)
# $70.00 total (NM/NM) (New) --> Removed
# $74.99 total (VG+/VG+)
# $85.00 total (M/M)
# $94.99 total (M/VG+)
# $85.00 total (M/NM)
# $84.99 total (M/NM)
# $91.98 total (M/M)
# $90.00 total (NM/NM)
# $105.00 total (M/M)
# $104.00 total (M/M)
# $116.98 total (M/M)
# $111.21 total (NM/NM)
# $130.99 total (NM/NM)
# $155.50 total (M/NM)
# $216.22 total (M/M)
# $333.00 total (M/M)
# Inserted --> $604.99 total (M/M)
# (24)
# Frank Ocean - Blond (2xLP, Album)
# https://www.discogs.com/sell/release/9412062?ships_from=United+States&sort=price%2Casc
# ...
